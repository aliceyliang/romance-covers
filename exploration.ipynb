# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import ipyplot

# %% [markdown]
# This project looks at changes in Romance books as selected by Publishers Weekly over the last ten years (2013-2023).
#
# Publishers Weekly has been making a list of books by genre since 2011. (In the first two years, data formats varied but that information could be added.) They took submissions from major publishers for any books published in that genre, and in most years selected the top 10.

# %% [markdown]
# ## Extract & clean book metadata

# %%
def find_body_index(body, phrase):
    return min([body.index(x) for x in body if phrase in x.text])

def find_article_lede(body):
    start_top_10 = find_body_index(body, "Top 10") + 1 
    return body[:start_top_10-1][0].text

# %%
def clean_isbn(isbn):
    return re.sub(r"[\s-]", "", isbn)

# %%
def clean_info(info_text, year, season):
    info_text = info_text.replace("C.L. Wilson","CL Wilson").replace("M.L. Buchman","ML Buchman") # replacing when multiple periods
    author = info_text[:info_text.index('. ')]
    publisher = info_text[info_text.index('. ')+2:info_text.index(', ')]
    price = ''
    isbn = ''
    type = ''
    if year < 2019:
        date = info_text[info_text.index(', ')+2:] ## add year if not avail
    elif (year==2019 and season=="Fall"):
        split = info_text[info_text.index('. ')+2:].split(", ")
        for s in split:
            if s[0]=="$":
                price = s
            elif "ISBN" in s:
                isbn = s.replace("ISBN ","")
            elif bool(re.match("^[A-Z]", s)):
                date = s
            else:
                type = s
    else:
        parens = re.search(r"\(([^$]*\$[^)]*)\)", info_text).group(1)
        date = info_text[info_text.index(', ')+2:info_text.index(parens)].replace("(","").strip() ## add year if not avail
        split = parens.split(", ")
        for s in split:
            if s[0]=="$":
                price = s
            elif "ISBN" in s:
                isbn = s.replace("ISBN ","")
            else:
                type = s
    return author, publisher, date, price, isbn, type

# %%
def clean_top_10_list(body, year, season):
    start_top_10 = find_body_index(body, "Top 10") + 1
    if year == 2018 or year >= 2022:
        end_top_10 = find_body_index(body, "Romance & Erotica")
    else:
        end_top_10 = find_body_index(body, "Listings")
    top_10_body = [x.text for x in body[start_top_10:end_top_10]]

    output = []
    for i,x in enumerate(top_10_body):
        if (year in (2013, 2014)) or (year == 2015 and season == "Spring"):
            book = {}
            book['year'] = year
            book['season'] = season
            book['title'] = x[:x.index('.')].strip()
            info = clean_info(x[x.index('.')+2:], year, season)
            book['author'] = info[0]
            book['publisher'] = info[1]
            book['date'] = info[2]
            output += [book]
        elif (year > 2012 and i%3 == 0) or (year == 2012 and i%2 == 0):
            book = {}
            book['year'] = year
            book['season'] = season
            book['title'] = x.strip()
        elif (year > 2012 and i%3 == 1) or (year == 2012 and i%2 == 0):
            info = clean_info(x, year, season)
            book['author'] = info[0]
            book['publisher'] = info[1]
            book['date'] = info[2]
            book['price'] = info[3]
            book['ISBN'] = clean_isbn(info[4])
            book['type'] = info[5]
        elif (year > 2012 and i%3 == 2):
            book['description'] = x
            output += [book]
    return output

# %%
def clean_listing_description(txt):
    txt = txt.replace(";",",").replace("hardcover $","hardcover, $").replace("trade paper ISBN","trade paper, ISBN") # typos if applicable
    output = {}

    title = txt[:txt.rfind(' by ')].strip()
    author = txt[txt.rfind(' by ')+4:txt.rfind('(')].strip()
    output.update({'title': title})
    output.update({'author': author})

    second_half = txt[txt.rfind('(')+1:].split(', ')

    for s in second_half:
        s = s.strip()
        if s[0]=="$":
            if len(s)>6:
                output.update({'type': re.sub(r'[$\d\.]', '', s).strip()})
                output.update({'price': re.sub(r'[a-zA-Z\s-]', '', s).strip()})
            else:
                output.update({'price': s})
        elif s[0:5]=="ISBN ":
            output.update({'ISBN': clean_isbn(s.replace("ISBN ",""))})
        elif bool(re.match("^[A-Z]", s)): # check date
            output.update({'date': s})
        elif bool(re.match("^[a-z]", s)): # check type
            output.update({'type': s})
    
    return output

# %%
def clean_listings(body, year, season):
    if year == 2018 or year >= 2022:
        end_top_10 = find_body_index(body, "Romance & Erotica")
    else:
        end_top_10 = find_body_index(body, "Listings")
    listings = [x.text.strip() for x in body[end_top_10+1:] if x!="" and (len(x)>0 and x.text.strip()[0]!="(")] # remove short () lines in some years
    output = []
    for x in listings:

        ## typo in 2019
        if x == "Dared by the Bad Boy by Melonie Johnson (June 25, mass market,":
            x = ""
        if x.strip() == "$7.99, ISBN 978-1-250-19307-0). A Hollywood actress and a stuntman, who come from different backgrounds and had a mutual crush as teens, get a second chance at love on the set of a blockbuster movie.":
            x = "Dared by the Bad Boy by Melonie Johnson (June 25, mass market, $7.99, ISBN 978-1-250-19307-0). A Hollywood actress and a stuntman, who come from different backgrounds and had a mutual crush as teens, get a second chance at love on the set of a blockbuster movie."
        ## end typo

        if len(x) > 0 and len(x) <= 40: ## proxy for identifying publisher
            publisher = x
        else:
            book = {}
            if ')' in x: # some errors when extra paragraph was added
                book['year'] = year
                book['season'] = season
                book['publisher'] = publisher.strip()
                info = re.search(r"\(([^$]*\$[^)]*)\)", x).group(1)
                end_info_position = x.find(info)+len(info)
                book.update(clean_listing_description(x[:end_info_position]))
                desc = x[end_info_position+1:]
                if desc[0:2] == '. ':
                    book['description'] = desc[2:]
                else:
                    book['description'] = desc
                output += [book]
    return output

# %%
def clean_article(year, season, url):
    
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text)
    body = soup.find("div",{"class":"article-body"}).find_all('p')

    top_10 = clean_top_10_list(body, int(year), season)
    listings = clean_listings(body, int(year), season)
    
    return top_10, listings

# %%
from csv import DictReader
# open file in read mode
with open("urls.csv", 'r') as f:
    dict_reader = DictReader(f)
    urls = list(dict_reader)

# %%
def clean_all(urls):
    all_top_10 = []
    all_listings = []
    for i, u in enumerate(urls):

        cleaned = clean_article(u['year'], u['season'], u['url'])
        all_top_10 += cleaned[0]
        all_listings += cleaned[1]

    df_top_10 = pd.DataFrame(all_top_10)
    df_all_listings = pd.DataFrame(all_listings)

    return df_top_10, df_all_listings

# %%
df_top_10, df_all_listings = clean_all(urls[4:])

# %%
## In earlier years the ISBN for the top 10 list was not included but can be matched in the listings info (in most cases)
df_top_10['lower_title'] = [x.lower() for x in df_top_10['title']]
df_all_listings['lower_title'] = [x.lower() for x in df_all_listings['title']]
df_top_10 = df_top_10.merge(df_all_listings[['year','season','lower_title','ISBN']], how='left', on=['year','season','lower_title'], suffixes=[None,'_from_listings'])
df_top_10['ISBN_combined'] = df_top_10['ISBN_from_listings'].fillna(df_top_10['ISBN'])
df_top_10 = df_top_10.drop(columns=['ISBN','ISBN_from_listings','lower_title'])
df_top_10 = df_top_10.rename(columns={'ISBN_combined':'ISBN'})

# %%
# Export to CSVs to pick up here
df_top_10.to_csv('top_10.csv')
df_all_listings.to_csv('listings.csv')

# %% [markdown]
# ## Explore book metadata

# %%
df_top_10
# Out:
#      year  season                                              title  \
# 0    2013  Spring                                    Bungalow Nights
# 1    2013  Spring                                  The Lemon Orchard
# 2    2013  Spring                                 Once Again a Bride
# 3    2013  Spring                                   Big Girl Panties
# 4    2013  Spring                           Sins of a Ruthless Rogue
# ..    ...     ...                                                ...
# 205  2023  Spring                                       Star Bringer
# 206  2023  Spring                           The True Love Experiment
# 207  2023  Spring  Unladylike Lessons in Love: A Marleigh Sisters...
# 208  2023  Spring                                        Wild Things
# 209  2023  Spring                          Wings Once Cursed & Bound
#
#                          author               publisher     date  \
# 0              Christie Ridgway                     HQN  Feb. 26
# 1                   Luanne Rice    Viking/Pamela Dorman   July 2
# 2                  Jane Ashford  Sourcebooks Casablanca   Feb. 1
# 3           Stephanie Evanovich          William Morrow   July 9
# 4                   Anna Randol                    Avon  Mar. 26
# ..                          ...                     ...      ...
# 205  Tracy Wolff and Nina Croft               Red Tower  July 11
# 206            Christina Lauren                 Gallery   May 16
# 207                Amita Murray                    Avon   May 16
# 208                   Laura Kay                 Vintage   May 23
# 209                 Piper Drake  Sourcebooks Casablanca  Apr. 11
#
#                   price type  \
# 0                   NaN  NaN
# 1                   NaN  NaN
# 2                   NaN  NaN
# 3                   NaN  NaN
# 4                   NaN  NaN
# ..                  ...  ...
# 205              $29.99
# 206              $27.99
# 207  $17.99 trade paper
# 208     $17 trade paper
# 209  $16.99 trade paper
#
#                                            description           ISBN
# 0                                                  NaN  9780373777457
# 1                                                  NaN  9780670025275
# 2                                                  NaN  9781402276729
# 3                                                  NaN  9780062224842
# 4                                                  NaN  9780062231352
# ..                                                 ...            ...
# 205  Bestselling YA author Wolff teams up with Crof...  9781649374066
# 206  Romance author Fizzy, a fan favorite character...  9781982173432
# 207  Murray’s Regency debut and series launch stars...  9780063296480
# 208  A queer found family leaves the city for a co-...  9780593470053
# 209  Drake launches her Mythwoven series with a rom...  9781492683865
#
# [210 rows x 10 columns]

# %%
df_all_listings
# Out:
#       year  season    publisher                                      title  \
# 0     2013  Spring         Avon                   Sins of a Ruthless Rogue
# 1     2013  Spring         Avon                                 Run to You
# 2     2013  Spring         Avon  Love at First Sight: A Cupid, Texas Novel
# 3     2013  Spring         Avon                        Any Duchess Will Do
# 4     2013  Spring         Avon                          Once Upon a Tower
# ...    ...     ...          ...                                        ...
# 1108  2023  Spring      Vintage                                Sizzle Reel
# 1109  2023  Spring  W x Wattpad                                   The Bite
# 1110  2023  Spring        Zebra                             He’s My Cowboy
# 1111  2023  Spring        Zebra                            Strawberry Lane
# 1112  2023  Spring        Zebra               What Happens in the Ballroom
#
#                                                  author     date         type  \
# 0                                           Anna Randol  Mar. 26  mass market
# 1                                         Rachel Gibson  Apr. 30  mass market
# 2                                            Lori Wilde   May 28  mass market
# 3                                            Tessa Dare   May 28  mass market
# 4                                          Eloisa James   May 28  mass market
# ...                                                 ...      ...          ...
# 1108                                   Carlyn Greenwald  Apr. 18  trade paper
# 1109                                        Z.W. Taylor   Feb. 7  trade paper
# 1110  Diana Palmer, Delores Fossen, and Rebecca Zanetti  June 27  mass market
# 1111                                        Jodi Thomas  Apr. 25  trade paper
# 1112                                   Sabrina Jeffries  Mar. 28  mass market
#
#        price           ISBN  \
# 0      $7.99  9780062231352
# 1      $7.99  9780062069146
# 2      $7.99  9780062218933
# 3      $5.99  9780062240125
# 4      $7.99  9780062223876
# ...      ...            ...
# 1108     $17  9780593468197
# 1109  $17.99  9781990259654
# 1110   $9.99  9781420155327
# 1111  $16.95  9781420155075
# 1112   $8.99  9781420153798
#
#                                             description  \
# 0     Amid the glittering palaces of Russia and the ...
# 1      returns to Texas for the second in the Milita...
# 2     Wilde launches a series set in a small Texas t...
# 3     Dare continues her bestselling Spindle Cove hi...
# 4     James continues her bestselling fairy tale ser...
# ...                                                 ...
# 1108   follows newly out bisexual Luna as she naviga...
# 1109  The heroine of Taylor’s paranormal debut flees...
# 1110   brings together three western romance novella...
# 1111   launches a new series with the love story bet...
# 1112  The second Designing Debutants Regency romance...
#
#                                     lower_title
# 0                      sins of a ruthless rogue
# 1                                    run to you
# 2     love at first sight: a cupid, texas novel
# 3                           any duchess will do
# 4                             once upon a tower
# ...                                         ...
# 1108                                sizzle reel
# 1109                                   the bite
# 1110                             he’s my cowboy
# 1111                            strawberry lane
# 1112               what happens in the ballroom
#
# [1113 rows x 11 columns]

# %%
# It turns out that some top 10 chosen were not part of listings... in some years they seemed to have excluded them on purpose.

unique_isbns = [x for x in list(set(list(df_top_10['ISBN']) + list(df_all_listings['ISBN']))) if x!=""]
print(len(unique_isbns), "unique ISBNs")
# Out:
# 1199 unique ISBNs

# %% [markdown]
# ## Extract book covers and Google Books metadata

# %%
def google_books_info_by_isbn(isbn):

    isbn = str(isbn)
    if isbn == "nan":
        return {}
    
    isbn = re.sub(r"[\s-]", "", isbn)
    url = "https://www.googleapis.com/books/v1/volumes?q=isbn:{}".format(isbn)
    r = requests.get(url)
    print(url)
    if "totalItems" in r.json().keys():
        if r.json()["totalItems"] == 0:
            url = "https://www.googleapis.com/books/v1/volumes?q=isbn_13:{}".format(isbn)
            r = requests.get(url)
            print("isbn13", url)

            if r.json()["totalItems"] == 0:
                print("NONE FOUND", url)
                return {'ISBN':isbn}

        elif r.json()["totalItems"] > 1:
            print("multiple items", url)

        data = r.json()['items'][0] ## check if multiple items?
        output = {'ISBN': isbn}
        output.update({'id': data['id']}) 
        for x in ['title','description','pageCount','printedPageCount','maturityRating']: # title included for crosscheck
            if x in data['volumeInfo'].keys():
                output.update({'google_{}'.format(x): data['volumeInfo'][x]})
        if 'imageLinks' in data['volumeInfo'].keys(): # add images
            for y in ['thumbnail','smallThumbnail']: # other types available?
                if y in data['volumeInfo']['imageLinks'].keys():
                    output.update({'google_{}'.format(y): data['volumeInfo']['imageLinks'][y]})
        return output
    else:
        print(r.json())

# %%
def get_all_google_books_data(isbn_list):
    output = []
    for i,b in enumerate(isbn_list):
        if (i%90==0 and i>0): ## THIS IS HERE FOR RATE LIMITING - REQUEST HIGHER RATE LIMIT?
            print(i, "Sleeping")
            time.sleep(61)
        if i == 1000:
            time.sleep(100)
        print(i)
        output += [google_books_info_by_isbn(b)]
        df = pd.DataFrame(output)
    return df

google_books_data = get_all_google_books_data(unique_isbns)
google_books_data.to_csv("google_books_data.csv")

# %%
google_books_data
# Out:
#                ISBN            id                google_title  \
# 0     9781250767943  MrZ8zQEACAAJ                  Float Plan
# 1     9781492616405  AfUQkAEACAAJ               One More Kiss
# 2     9781501124235  P6o5DAAAQBAJ    Everywhere and Every Way
# 3     9780758290175  Aw1QAgAAQBAJ            The Sinners Club
# 4     9781492621218  8CtsrgEACAAJ          Missed Connections
# ...             ...           ...                         ...
# 1194  9781492602118  15EXoAEACAAJ         The Rake's Handbook
# 1195  9780373789238  PkfXjwEACAAJ      Sunset in Central Park
# 1196  9780765380432  KHXpswEACAAJ            Starlight Nights
# 1197  9781626493742  mdt6jgEACAAJ  The Secret of Hunter's Bog
# 1198  9781101884485  0fLaCwAAQBAJ    Everything I Left Unsaid
#
#                                      google_description  google_pageCount  \
# 0     "The perfect escape. Fresh, funny, and romanti...             272.0
# 1     "Spectacular...so much more than just a romanc...             352.0
# 2     "Ever the responsible eldest brother, Caleb Pi...             384.0
# 3     Nobleman Jack Lennox takes on the guise of his...             304.0
# 4     CONTEMPORARY ROMANCESarah has been looking for...             320.0
# ...                                                 ...               ...
# 1194  The infamous author of "The Rake's Handbook," ...             352.0
# 1195  When she finally admits to herself she has fee...             384.0
# 1196  In this sizzling companion to the critically a...             400.0
# 1197  For Koichi McNab, the shop he and his twin sis...               NaN
# 1198  Fans of Jodi Ellen Malpas, K. Bromberg, and Jo...             353.0
#
#      google_maturityRating                                   google_thumbnail  \
# 0               NOT_MATURE  http://books.google.com/books/content?id=MrZ8z...
# 1               NOT_MATURE  http://books.google.com/books/content?id=AfUQk...
# 2               NOT_MATURE  http://books.google.com/books/content?id=P6o5D...
# 3                   MATURE  http://books.google.com/books/content?id=Aw1QA...
# 4               NOT_MATURE  http://books.google.com/books/content?id=8Ctsr...
# ...                    ...                                                ...
# 1194            NOT_MATURE  http://books.google.com/books/content?id=15EXo...
# 1195            NOT_MATURE  http://books.google.com/books/content?id=PkfXj...
# 1196            NOT_MATURE  http://books.google.com/books/content?id=KHXps...
# 1197            NOT_MATURE  http://books.google.com/books/content?id=mdt6j...
# 1198            NOT_MATURE  http://books.google.com/books/content?id=0fLaC...
#
#                                   google_smallThumbnail
# 0     http://books.google.com/books/content?id=MrZ8z...
# 1     http://books.google.com/books/content?id=AfUQk...
# 2     http://books.google.com/books/content?id=P6o5D...
# 3     http://books.google.com/books/content?id=Aw1QA...
# 4     http://books.google.com/books/content?id=8Ctsr...
# ...                                                 ...
# 1194  http://books.google.com/books/content?id=15EXo...
# 1195  http://books.google.com/books/content?id=PkfXj...
# 1196  http://books.google.com/books/content?id=KHXps...
# 1197  http://books.google.com/books/content?id=mdt6j...
# 1198  http://books.google.com/books/content?id=0fLaC...
#
# [1199 rows x 8 columns]

# %% [markdown]
# ## Display book covers

# %%
df_top_10_csv = pd.read_csv('top_10.csv')
df_google_books_csv = pd.read_csv('google_books_data.csv')

# %%
top_10_merged = df_top_10_csv.merge(df_google_books_csv, how='left', on='ISBN')

# %%
for year in range(2013,2024):
    print(year)
    t = top_10_merged.loc[(top_10_merged['year']==year) & (top_10_merged['ISBN']!="")] 
    ipyplot.plot_images(list(t['google_smallThumbnail']), list(t['title']), img_width=100)
# Out:
# 2013
#     <style>
#         #ipyplot-html-viewer-toggle-WECrMosue7Sf6ri9sM7Bud {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-WECrMosue7Sf6ri9sM7Bud {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-WECrMosue7Sf6ri9sM7Bud {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-WECrMosue7Sf6ri9sM7Bud:checked ~ #ipyplot-html-viewer-textarea-WECrMosue7Sf6ri9sM7Bud {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-WECrMosue7Sf6ri9sM7Bud:checked + #ipyplot-html-viewer-label-WECrMosue7Sf6ri9sM7Bud:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-WECrMosue7Sf6ri9sM7Bud">
#         <label id="ipyplot-html-viewer-label-WECrMosue7Sf6ri9sM7Bud" for="ipyplot-html-viewer-toggle-WECrMosue7Sf6ri9sM7Bud">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-WECrMosue7Sf6ri9sM7Bud" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-NAnKLkwbaPmPYarPhYxCiG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-NAnKLkwbaPmPYarPhYxCiG">
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-NmHP62CJESazR9viuxKKC5" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Bungalow Nights</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=meJabTY-yTUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=meJabTY-yTUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-NmHP62CJESazR9viuxKKC5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-EVuBaogJfvLwk6m4KDFuAQ" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Lemon Orchard</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=QzIK9PsxwK4C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=QzIK9PsxwK4C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-EVuBaogJfvLwk6m4KDFuAQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-nwVRfgc9ZcHdRSQnTzq4Yn" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Once Again a Bride</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=UYp7MAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=UYp7MAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-nwVRfgc9ZcHdRSQnTzq4Yn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-HUB8dWFwG4ffb7NiTCnHqh" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Big Girl Panties</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">nan</h4><img src="nan"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-HUB8dWFwG4ffb7NiTCnHqh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-7CdqYbW9nMHYw7PSRbSYwb" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Sins of a Ruthless Rogue</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-7CdqYbW9nMHYw7PS
#         <style>
#         #ipyplot-imgs-container-div-NAnKLkwbaPmPYarPhYxCiG {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-NAnKLkwbaPmPYarPhYxCiG">
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-NmHP62CJESazR9viuxKKC5" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Bungalow Nights</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=meJabTY-yTUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=meJabTY-yTUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-NmHP62CJESazR9viuxKKC5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-EVuBaogJfvLwk6m4KDFuAQ" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Lemon Orchard</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=QzIK9PsxwK4C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=QzIK9PsxwK4C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-EVuBaogJfvLwk6m4KDFuAQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-nwVRfgc9ZcHdRSQnTzq4Yn" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Once Again a Bride</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=UYp7MAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=UYp7MAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-nwVRfgc9ZcHdRSQnTzq4Yn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-HUB8dWFwG4ffb7NiTCnHqh" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Big Girl Panties</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">nan</h4><img src="nan"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-HUB8dWFwG4ffb7NiTCnHqh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-7CdqYbW9nMHYw7PSRbSYwb" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Sins of a Ruthless Rogue</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-7CdqYbW9nMHYw7PSRbSYwb">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-Jkdgz8SvnTN8QCRvmLCCwH" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">All He Ever Desired</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=Av9yMAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=Av9yMAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-Jkdgz8SvnTN8QCRvmLCCwH">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-NAnKLkwbaPmPYarPhYxCiG">
#         <div id="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG-HoSt5bkdL6zX4maKXoE9eN" class="ipyplot-content-div-NAnKLkwbaPmPYarPhYxCiG">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Just One Kiss</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5fPqvOvMaHoC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4>
# 2014
#     <style>
#         #ipyplot-html-viewer-toggle-eqZ7iQu3TnRQa85a7ekPnD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-eqZ7iQu3TnRQa85a7ekPnD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-eqZ7iQu3TnRQa85a7ekPnD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-eqZ7iQu3TnRQa85a7ekPnD:checked ~ #ipyplot-html-viewer-textarea-eqZ7iQu3TnRQa85a7ekPnD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-eqZ7iQu3TnRQa85a7ekPnD:checked + #ipyplot-html-viewer-label-eqZ7iQu3TnRQa85a7ekPnD:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-eqZ7iQu3TnRQa85a7ekPnD">
#         <label id="ipyplot-html-viewer-label-eqZ7iQu3TnRQa85a7ekPnD" for="ipyplot-html-viewer-toggle-eqZ7iQu3TnRQa85a7ekPnD">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-eqZ7iQu3TnRQa85a7ekPnD" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-YzycSPk7KYsQTk8fBgccsr {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-YzycSPk7KYsQTk8fBgccsr {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-YzycSPk7KYsQTk8fBgccsr">
#     <div class="ipyplot-placeholder-div-YzycSPk7KYsQTk8fBgccsr">
#         <div id="ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr-jzzQ4foJ4HfkQ3WnhGbt7A" class="ipyplot-content-div-YzycSPk7KYsQTk8fBgccsr">
#             <h4 style="font-size: 12px; word-wrap: break-word;">
ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Neighbor Favor</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=3JmOEAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=3JmOEAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2-HsWzraL2SrDDGzh4XFbkEv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FJXjmtSUNjd2yh9UUemDk2">
#         <div id="ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2-EBhuU8rBCoKCCLuDs7XfGB" class="ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Star Bringer</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=DUd9EAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=DUd9EAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2-EBhuU8rBCoKCCLuDs7XfGB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FJXjmtSUNjd2yh9UUemDk2">
#         <div id="ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2-gXDGMFfkPjGL2uL8vn6Swp" class="ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The True Love Experiment</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=EUdgzwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=EUdgzwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2-gXDGMFfkPjGL2uL8vn6Swp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-FJXjmtSUNjd2yh9UUemDk2">
#         <div id="ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2-nNeSYCNwviR9BCok8pm5gH" class="ipyplot-content-div-FJXjmtSUNjd2yh9UUemDk2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Unladylike Lessons in Love: A Marleigh Sisters Novel</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right:

# %%
df_listings_csv = pd.read_csv('listings.csv')

# %%
listings_merged = df_listings_csv.merge(df_google_books_csv, how='left', on='ISBN')

# %%
for year in range(2013,2024):
    print(year)
    t = listings_merged.loc[(listings_merged['year']==year) & (listings_merged['ISBN']!="")] 
    ipyplot.plot_images(list(t['google_smallThumbnail']), list(t['title']), img_width=100)
# Out:
# 2013
#     <style>
#         #ipyplot-html-viewer-toggle-kWwvT2QQeF6MPZfEdirgKp {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kWwvT2QQeF6MPZfEdirgKp {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kWwvT2QQeF6MPZfEdirgKp {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kWwvT2QQeF6MPZfEdirgKp:checked ~ #ipyplot-html-viewer-textarea-kWwvT2QQeF6MPZfEdirgKp {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kWwvT2QQeF6MPZfEdirgKp:checked + #ipyplot-html-viewer-label-kWwvT2QQeF6MPZfEdirgKp:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-kWwvT2QQeF6MPZfEdirgKp">
#         <label id="ipyplot-html-viewer-label-kWwvT2QQeF6MPZfEdirgKp" for="ipyplot-html-viewer-toggle-kWwvT2QQeF6MPZfEdirgKp">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-kWwvT2QQeF6MPZfEdirgKp" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-aUwP5QFZCw5iVEEFFnna6S {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-aUwP5QFZCw5iVEEFFnna6S">
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-eoGRE7iczXwA4vvzc4fjYj" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Sins of a Ruthless Rogue</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-eoGRE7iczXwA4vvzc4fjYj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-VyBrcLmy6hRVnsKe3UND5X" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Run to You</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-VyBrcLmy6hRVnsKe3UND5X">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-aUcpQu587HREsaJFBgKvsW" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Love at First Sight: A Cupid, Texas Novel</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-aUcpQu587HREsaJFBgKvsW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-iX3eZNXZPCVfQDNGcGq6Gh" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Any Duchess Will Do</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-iX3eZNXZPCVfQDNGcGq6Gh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-hSRTywMNSMEEb7PiYVdnVM" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Once Upon a Tower</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"
#         <style>
#         #ipyplot-imgs-container-div-aUwP5QFZCw5iVEEFFnna6S {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-aUwP5QFZCw5iVEEFFnna6S">
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-eoGRE7iczXwA4vvzc4fjYj" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Sins of a Ruthless Rogue</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-eoGRE7iczXwA4vvzc4fjYj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-VyBrcLmy6hRVnsKe3UND5X" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Run to You</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-VyBrcLmy6hRVnsKe3UND5X">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-aUcpQu587HREsaJFBgKvsW" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Love at First Sight: A Cupid, Texas Novel</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-aUcpQu587HREsaJFBgKvsW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-iX3eZNXZPCVfQDNGcGq6Gh" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Any Duchess Will Do</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-iX3eZNXZPCVfQDNGcGq6Gh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-hSRTywMNSMEEb7PiYVdnVM" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Once Upon a Tower</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-hSRTywMNSMEEb7PiYVdnVM">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-LtXE6ChUFnw4iYpmREZFeq" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">An English Bride in Scotland</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=j_TzngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=j_TzngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-LtXE6ChUFnw4iYpmREZFeq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-aUwP5QFZCw5iVEEFFnna6S">
#         <div id="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S-Se9sn5yMYjjc8YQKR3fgi9" class="ipyplot-content-div-aUwP5QFZCw5iVEEFFnna6S">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Sum of All Kisses</h4>
#             <h4 style="font-size: 9px; padding-left: 10px;
# 2014
#     <style>
#         #ipyplot-html-viewer-toggle-RYy9FerjUCT36GraN64KBM {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-RYy9FerjUCT36GraN64KBM {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-RYy9FerjUCT36GraN64KBM {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-RYy9FerjUCT36GraN64KBM:checked ~ #ipyplot-html-viewer-textarea-RYy9FerjUCT36GraN64KBM {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-RYy9FerjUCT36GraN64KBM:checked + #ipyplot-html-viewer-label-RYy9FerjUCT36GraN64KBM:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-RYy9FerjUCT36GraN64KBM">
#         <label id="ipyplot-html-viewer-label-RYy9FerjUCT36GraN64KBM" for="ipyplot-html-viewer-toggle-RYy9FerjUCT36GraN64KBM">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-RYy9FerjUCT36GraN64KBM" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-Y6DnxXtYUuNj88AxAoRqSv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Y6DnxXtYUuNj88AxAoRqSv">
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-mVWcze2L7xHqUsXsnJgwLi" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Beautifully Damaged</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-mVWcze2L7xHqUsXsnJgwLi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-Zt88wYxeE8gAFLkudjmiHA" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">A Husband’s Regret</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-Zt88wYxeE8gAFLkudjmiHA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-W2o68rkqw88FxnKJJ6DqK5" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Collide</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-W2o68rkqw88FxnKJJ6DqK5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-6BPQnk4GJHbrDk9FB5jGkX" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Awakening of Miss Prim</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-6BPQnk4GJHbrDk9FB5jGkX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-mZiCasy3HmmNvoQKicMzh4" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Nowhere But Here</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&
#         <style>
#         #ipyplot-imgs-container-div-Y6DnxXtYUuNj88AxAoRqSv {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-Y6DnxXtYUuNj88AxAoRqSv">
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-mVWcze2L7xHqUsXsnJgwLi" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Beautifully Damaged</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-mVWcze2L7xHqUsXsnJgwLi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-Zt88wYxeE8gAFLkudjmiHA" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">A Husband’s Regret</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-Zt88wYxeE8gAFLkudjmiHA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-W2o68rkqw88FxnKJJ6DqK5" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Collide</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-W2o68rkqw88FxnKJJ6DqK5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-6BPQnk4GJHbrDk9FB5jGkX" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Awakening of Miss Prim</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-6BPQnk4GJHbrDk9FB5jGkX">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-mZiCasy3HmmNvoQKicMzh4" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Nowhere But Here</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-mZiCasy3HmmNvoQKicMzh4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-fwgRWSzFYCUMfFCMGcy6Md" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">When the Duke Was Wicked</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=vYmrnQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=vYmrnQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-fwgRWSzFYCUMfFCMGcy6Md">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-Y6DnxXtYUuNj88AxAoRqSv">
#         <div id="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv-b6w5QeubRQzntLh5UrByFC" class="ipyplot-content-div-Y6DnxXtYUuNj88AxAoRqSv">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Winter King</h4>
#             <h4 style="font-size: 9px; padding-left: 1
# 2015
#     <style>
#         #ipyplot-html-viewer-toggle-3p8eavNteFTWKzqaSEon52 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3p8eavNteFTWKzqaSEon52 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3p8eavNteFTWKzqaSEon52 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3p8eavNteFTWKzqaSEon52:checked ~ #ipyplot-html-viewer-textarea-3p8eavNteFTWKzqaSEon52 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3p8eavNteFTWKzqaSEon52:checked + #ipyplot-html-viewer-label-3p8eavNteFTWKzqaSEon52:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-3p8eavNteFTWKzqaSEon52">
#         <label id="ipyplot-html-viewer-label-3p8eavNteFTWKzqaSEon52" for="ipyplot-html-viewer-toggle-3p8eavNteFTWKzqaSEon52">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea