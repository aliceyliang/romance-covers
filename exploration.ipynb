# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import ipyplot

# %% [markdown]
# This project looks at changes in Romance books as selected by Publishers Weekly over the last ten years (2013-2023).
#
# Publishers Weekly has been making a list of books by genre since 2011. (In the first two years, data formats varied but that information could be added.) They took submissions from major publishers for any books published in that genre, and in most years selected the top 10.

# %% [markdown]
# ## Extract & clean book metadata

# %%
def find_body_index(body, phrase):
    return min([body.index(x) for x in body if phrase in x.text])

def find_article_lede(body):
    start_top_10 = find_body_index(body, "Top 10") + 1 
    return body[:start_top_10-1][0].text

# %%
def clean_isbn(isbn):
    return re.sub(r"[\s-]", "", isbn)

# %%
def clean_info(info_text, year, season):
    info_text = info_text.replace("C.L. Wilson","CL Wilson").replace("M.L. Buchman","ML Buchman") # replacing when multiple periods
    author = info_text[:info_text.index('. ')]
    publisher = info_text[info_text.index('. ')+2:info_text.index(', ')]
    price = ''
    isbn = ''
    type = ''
    if year < 2019:
        date = info_text[info_text.index(', ')+2:] ## add year if not avail
    elif (year==2019 and season=="Fall"):
        split = info_text[info_text.index('. ')+2:].split(", ")
        for s in split:
            if s[0]=="$":
                price = s
            elif "ISBN" in s:
                isbn = s.replace("ISBN ","")
            elif bool(re.match("^[A-Z]", s)):
                date = s
            else:
                type = s
    else:
        parens = re.search(r"\(([^$]*\$[^)]*)\)", info_text).group(1)
        date = info_text[info_text.index(', ')+2:info_text.index(parens)].replace("(","").strip() ## add year if not avail
        split = parens.split(", ")
        for s in split:
            if s[0]=="$":
                price = s
            elif "ISBN" in s:
                isbn = s.replace("ISBN ","")
            else:
                type = s
    return author, publisher, date, price, isbn, type

# %%
def clean_top_10_list(body, year, season):
    start_top_10 = find_body_index(body, "Top 10") + 1
    if year == 2018 or year >= 2022:
        end_top_10 = find_body_index(body, "Romance & Erotica")
    else:
        end_top_10 = find_body_index(body, "Listings")
    top_10_body = [x.text for x in body[start_top_10:end_top_10]]

    output = []
    for i,x in enumerate(top_10_body):
        if year in (2013, 2014):
            book = {}
            book['year'] = year
            book['season'] = season
            book['title'] = x[:x.index('.')].strip()
            info = clean_info(x[x.index('.')+2:], year, season)
            book['author'] = info[0]
            book['publisher'] = info[1]
            book['date'] = info[2]
            output += [book]
        elif (year > 2012 and i%3 == 0) or (year == 2012 and i%2 == 0):
            book = {}
            book['year'] = year
            book['season'] = season
            book['title'] = x.strip()
        elif (year > 2012 and i%3 == 1) or (year == 2012 and i%2 == 0):
            info = clean_info(x, year, season)
            book['author'] = info[0]
            book['publisher'] = info[1]
            book['date'] = info[2]
            book['price'] = info[3]
            book['ISBN'] = clean_isbn(info[4])
            book['type'] = info[5]
        elif (year > 2012 and i%3 == 2):
            book['description'] = x
            output += [book]
    return output

# %%
def clean_listing_description(txt):
    txt = txt.replace(";",",").replace("hardcover $","hardcover, $").replace("trade paper ISBN","trade paper, ISBN") # typos if applicable
    output = {}

    title = txt[:txt.rfind(' by ')].strip()
    author = txt[txt.rfind(' by ')+4:txt.rfind('(')].strip()
    output.update({'title': title})
    output.update({'author': author})

    second_half = txt[txt.rfind('(')+1:].split(', ')

    for s in second_half:
        s = s.strip()
        if s[0]=="$":
            if len(s)>6:
                output.update({'type': re.sub(r'[$\d\.]', '', s).strip()})
                output.update({'price': re.sub(r'[a-zA-Z\s-]', '', s).strip()})
            else:
                output.update({'price': s})
        elif s[0:5]=="ISBN ":
            output.update({'ISBN': clean_isbn(s.replace("ISBN ",""))})
        elif bool(re.match("^[A-Z]", s)): # check date
            output.update({'date': s})
        elif bool(re.match("^[a-z]", s)): # check type
            output.update({'type': s})
    
    return output

# %%
def clean_listings(body, year, season):
    if year == 2018 or year >= 2022:
        end_top_10 = find_body_index(body, "Romance & Erotica")
    else:
        end_top_10 = find_body_index(body, "Listings")
    listings = [x.text.strip() for x in body[end_top_10+1:] if x!="" and (len(x)>0 and x.text.strip()[0]!="(")] # remove short () lines in some years
    output = []
    for x in listings:

        ## typo in 2019
        if x == "Dared by the Bad Boy by Melonie Johnson (June 25, mass market,":
            x = ""
        if x.strip() == "$7.99, ISBN 978-1-250-19307-0). A Hollywood actress and a stuntman, who come from different backgrounds and had a mutual crush as teens, get a second chance at love on the set of a blockbuster movie.":
            x = "Dared by the Bad Boy by Melonie Johnson (June 25, mass market, $7.99, ISBN 978-1-250-19307-0). A Hollywood actress and a stuntman, who come from different backgrounds and had a mutual crush as teens, get a second chance at love on the set of a blockbuster movie."
        ## end typo

        if len(x) > 0 and len(x) <= 40: ## proxy for identifying publisher
            publisher = x
        else:
            book = {}
            if ')' in x: # some errors when extra paragraph was added
                book['year'] = year
                book['season'] = season
                book['publisher'] = publisher.strip()
                info = re.search(r"\(([^$]*\$[^)]*)\)", x).group(1)
                end_info_position = x.find(info)+len(info)
                book.update(clean_listing_description(x[:end_info_position]))
                desc = x[end_info_position+1:]
                if desc[0:2] == '. ':
                    book['description'] = desc[2:]
                else:
                    book['description'] = desc
                output += [book]
    return output

# %%
def clean_article(year, season, url):
    
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text)
    body = soup.find("div",{"class":"article-body"}).find_all('p')

    top_10 = clean_top_10_list(body, int(year), season)
    listings = clean_listings(body, int(year), season)
    
    return top_10, listings

# %%
from csv import DictReader
# open file in read mode
with open("urls.csv", 'r') as f:
    dict_reader = DictReader(f)
    urls = list(dict_reader)

# %%
def clean_all(urls):
    all_top_10 = []
    all_listings = []
    for i, u in enumerate(urls):

        cleaned = clean_article(u['year'], u['season'], u['url'])
        all_top_10 += cleaned[0]
        all_listings += cleaned[1]

    df_top_10 = pd.DataFrame(all_top_10)
    df_all_listings = pd.DataFrame(all_listings)

    return df_top_10, df_all_listings

# %%
df_top_10, df_all_listings = clean_all(urls[4:])

# %%
## In earlier years the ISBN for the top 10 list was not included but can be matched in the listings info (in most cases)
df_top_10 = df_top_10.merge(df_all_listings[['year','season','title','author','ISBN']], how='left', on=['year','season','title','author'], suffixes=[None,'_from_listings'])
df_top_10['ISBN_combined'] = df_top_10['ISBN_from_listings'].fillna(df_top_10['ISBN'])
df_top_10 = df_top_10.drop(columns=['ISBN','ISBN_from_listings'])
df_top_10 = df_top_10.rename(columns={'ISBN_combined':'ISBN'})

# %%
# Export to CSVs to pick up here
df_top_10.to_csv('top_10.csv')
df_all_listings.to_csv('listings.csv')

# %% [markdown]
# ## Explore book metadata

# %%
df_top_10
# Out:
#      year  season                                              title  \
# 0    2013  Spring                                    Bungalow Nights
# 1    2013  Spring                                  The Lemon Orchard
# 2    2013  Spring                                 Once Again a Bride
# 3    2013  Spring                                   Big Girl Panties
# 4    2013  Spring                           Sins of a Ruthless Rogue
# ..    ...     ...                                                ...
# 198  2023  Spring                                       Star Bringer
# 199  2023  Spring                           The True Love Experiment
# 200  2023  Spring  Unladylike Lessons in Love: A Marleigh Sisters...
# 201  2023  Spring                                        Wild Things
# 202  2023  Spring                          Wings Once Cursed & Bound
#
#                          author               publisher     date  \
# 0              Christie Ridgway                     HQN  Feb. 26
# 1                   Luanne Rice    Viking/Pamela Dorman   July 2
# 2                  Jane Ashford  Sourcebooks Casablanca   Feb. 1
# 3           Stephanie Evanovich          William Morrow   July 9
# 4                   Anna Randol                    Avon  Mar. 26
# ..                          ...                     ...      ...
# 198  Tracy Wolff and Nina Croft               Red Tower  July 11
# 199            Christina Lauren                 Gallery   May 16
# 200                Amita Murray                    Avon   May 16
# 201                   Laura Kay                 Vintage   May 23
# 202                 Piper Drake  Sourcebooks Casablanca  Apr. 11
#
#                   price type  \
# 0                   NaN  NaN
# 1                   NaN  NaN
# 2                   NaN  NaN
# 3                   NaN  NaN
# 4                   NaN  NaN
# ..                  ...  ...
# 198              $29.99
# 199              $27.99
# 200  $17.99 trade paper
# 201     $17 trade paper
# 202  $16.99 trade paper
#
#                                            description           ISBN
# 0                                                  NaN  9780373777457
# 1                                                  NaN  9780670025275
# 2                                                  NaN  9781402276729
# 3                                                  NaN  9780062224842
# 4                                                  NaN  9780062231352
# ..                                                 ...            ...
# 198  Bestselling YA author Wolff teams up with Crof...  9781649374066
# 199  Romance author Fizzy, a fan favorite character...  9781982173432
# 200  Murray’s Regency debut and series launch stars...  9780063296480
# 201  A queer found family leaves the city for a co-...  9780593470053
# 202  Drake launches her Mythwoven series with a rom...  9781492683865
#
# [203 rows x 10 columns]

# %%
df_all_listings
# Out:
#       year  season    publisher                                      title  \
# 0     2013  Spring         Avon                   Sins of a Ruthless Rogue
# 1     2013  Spring         Avon                                 Run to You
# 2     2013  Spring         Avon  Love at First Sight: A Cupid, Texas Novel
# 3     2013  Spring         Avon                        Any Duchess Will Do
# 4     2013  Spring         Avon                          Once Upon a Tower
# ...    ...     ...          ...                                        ...
# 1108  2023  Spring      Vintage                                Sizzle Reel
# 1109  2023  Spring  W x Wattpad                                   The Bite
# 1110  2023  Spring        Zebra                             He’s My Cowboy
# 1111  2023  Spring        Zebra                            Strawberry Lane
# 1112  2023  Spring        Zebra               What Happens in the Ballroom
#
#                                                  author     date         type  \
# 0                                           Anna Randol  Mar. 26  mass market
# 1                                         Rachel Gibson  Apr. 30  mass market
# 2                                            Lori Wilde   May 28  mass market
# 3                                            Tessa Dare   May 28  mass market
# 4                                          Eloisa James   May 28  mass market
# ...                                                 ...      ...          ...
# 1108                                   Carlyn Greenwald  Apr. 18  trade paper
# 1109                                        Z.W. Taylor   Feb. 7  trade paper
# 1110  Diana Palmer, Delores Fossen, and Rebecca Zanetti  June 27  mass market
# 1111                                        Jodi Thomas  Apr. 25  trade paper
# 1112                                   Sabrina Jeffries  Mar. 28  mass market
#
#        price           ISBN                                        description
# 0      $7.99  9780062231352  Amid the glittering palaces of Russia and the ...
# 1      $7.99  9780062069146   returns to Texas for the second in the Milita...
# 2      $7.99  9780062218933  Wilde launches a series set in a small Texas t...
# 3      $5.99  9780062240125  Dare continues her bestselling Spindle Cove hi...
# 4      $7.99  9780062223876  James continues her bestselling fairy tale ser...
# ...      ...            ...                                                ...
# 1108     $17  9780593468197   follows newly out bisexual Luna as she naviga...
# 1109  $17.99  9781990259654  The heroine of Taylor’s paranormal debut flees...
# 1110   $9.99  9781420155327   brings together three western romance novella...
# 1111  $16.95  9781420155075   launches a new series with the love story bet...
# 1112   $8.99  9781420153798  The second Designing Debutants Regency romance...
#
# [1113 rows x 10 columns]

# %%
# It turns out that some top 10 chosen were not part of listings... in some years they seemed to have excluded them on purpose.

unique_isbns = [x for x in list(set(list(df_top_10['ISBN']) + list(df_all_listings['ISBN']))) if x!=""]
print(len(unique_isbns), "unique ISBNs")
# Out:
# 1199 unique ISBNs

# %% [markdown]
# ## Extract book covers and Google Books metadata

# %%
def google_books_info_by_isbn(isbn):
    isbn = str(isbn)

    isbn = re.sub(r"[\s-]", "", isbn)
    url = "https://www.googleapis.com/books/v1/volumes?q=isbn:{}".format(isbn)
    r = requests.get(url)
    print(url)
    if "totalItems" in r.json().keys():
        if r.json()["totalItems"] == 0:
            url = "https://www.googleapis.com/books/v1/volumes?q=isbn_13:{}".format(isbn)
            r = requests.get(url)
            print("isbn13", url)

            if r.json()["totalItems"] == 0:
                print("NONE FOUND", url)
                return {'ISBN':isbn}

        elif r.json()["totalItems"] > 1:
            print("multiple items", url)

        data = r.json()['items'][0] ## check if multiple items?
        output = {'ISBN': isbn}
        output.update({'id': data['id']}) 
        for x in ['title','description','pageCount','printedPageCount','maturityRating']: # title included for crosscheck
            if x in data['volumeInfo'].keys():
                output.update({'google_{}'.format(x): data['volumeInfo'][x]})
        if 'imageLinks' in data['volumeInfo'].keys(): # add images
            for y in ['thumbnail','smallThumbnail']: # other types available?
                if y in data['volumeInfo']['imageLinks'].keys():
                    output.update({'google_{}'.format(y): data['volumeInfo']['imageLinks'][y]})
        return output
    else:
        print(r.json())

# %%
def get_all_google_books_data(isbn_list):
    output = []
    for i,b in enumerate(isbn_list):
        if i%90==0 and i>0: ## THIS IS HERE FOR RATE LIMITING - REQUEST HIGHER RATE LIMIT?
            print(i, "Sleeping")
            time.sleep(61)
        print(i)
        output += [google_books_info_by_isbn(b)]
        df = pd.DataFrame(output)
    return df

google_books_data = get_all_google_books_data(unique_isbns)
google_books_data.to_csv("google_books_data.csv")
# Out:
# 0
# https://www.googleapis.com/books/v1/volumes?q=isbn:9780
# 3     9781503903852  M6dJtAEACAAJ                   Fling Club
# 4     9780425276488  IgQJDAAAQBAJ              Caged in Winter
# ...             ...           ...                          ...
# 1184  9780515151381  K_BvDwAAQBAJ     The Counterfeit Mistress
# 1185  9781420148107  OESwDwAAQBAJ                   Once a Spy
# 1186  9781250193070  h4TZugEACAAJ          Once Upon a Bad Boy
# 1187  9780062379849  PZuvoQEACAAJ  Love and Miss Communication
# 1188  9781250283788  x7WYEAAAQBAJ               Hello Stranger
#
#                                      google_description  google_pageCount  \
# 0     New York Times bestselling author Jenny Colgan...             400.0
# 1     "What do you mean, Ôshe's gone'?" Forensic psy...             384.0
# 2     When a recently engaged Manhattanite learns th...             352.0
# 3     It's revenge--sweet and hot--in the first book...             332.0
# 4     In this emotional and sexy New Adult debut fro...             303.0
# ...                                                 ...               ...
# 1184  THE BEAUTY. THE SPY. AND THE BEHOLDER. From th...             338.0
# 1185  Love and survival in the shadow of Waterloo . ...             385.0
# 1186  A Hollywood actress and a stuntman from differ...             320.0
# 1187  *Cosmopolitan Must-Read* *InStyle Book Club Pi...             400.0
# 1188  Sadie Montogmery has had good breaks and bad b...               0.0
#
#      google_maturityRating                                   google_thumbnail  \
# 0               NOT_MATURE  http://books.google.com/books/content?id=z1mkz...
# 1               NOT_MATURE  http://books.google.com/books/content?id=qNndu...
# 2               NOT_MATURE  http://books.google.com/books/content?id=yS3Cw...
# 3               NOT_MATURE  http://books.google.com/books/content?id=M6dJt...
# 4               NOT_MATURE  http://books.google.com/books/content?id=IgQJD...
# ...                    ...                                                ...
# 1184            NOT_MATURE  http://books.google.com/books/content?id=K_BvD...
# 1185            NOT_MATURE  http://books.google.com/books/content?id=OESwD...
# 1186            NOT_MATURE  http://books.google.com/books/content?id=h4TZu...
# 1187            NOT_MATURE  http://books.google.com/books/content?id=PZuvo...
# 1188            NOT_MATURE  http://books.google.com/books/content?id=x7WYE...
#
#                                   google_smallThumbnail
# 0     http://books.google.com/books/content?id=z1mkz...
# 1     http://books.google.com/books/content?id=qNndu...
# 2     http://books.google.com/books/content?id=yS3Cw...
# 3     http://books.google.com/books/content?id=M6dJt...
# 4     http://books.google.com/books/content?id=IgQJD...
# ...                                                 ...
# 1184  http://books.google.com/books/content?id=K_BvD...
# 1185  http://books.google.com/books/content?id=OESwD...
# 1186  http://books.google.com/books/content?id=h4TZu...
# 1187  http://books.google.com/books/content?id=PZuvo...
# 1188  http://books.google.com/books/content?id=x7WYE...
#
# [1189 rows x 8 columns]

# %% [markdown]
# ## Display book covers

# %%
df_top_10_csv = pd.read_csv('top_10.csv')
df_google_books_csv = pd.read_csv('google_books_data.csv')

# %%
top_10_merged = df_top_10_csv.merge(df_google_books_csv, how='left', on='ISBN')

# %%
for year in range(2013,2024):
    print(year)
    t = top_10_merged.loc[(top_10_merged['year']==year) & (top_10_merged['ISBN']!="")] 
    ipyplot.plot_images(list(t['google_smallThumbnail']), list(t['title']), img_width=100)
# Out:
# 2013
#     <style>
#         #ipyplot-html-viewer-toggle-9sc4YRuacj2q3a8idV9mPa {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label

#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3iHTapEPgTL4WNqnbTved9 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3iHTapEPgTL4WNqnbTved9 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3iHTapEPgTL4WNqnbTved9 img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-3iHTapEPgTL4WNqnbTved9 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3iHTapEPgTL4WNqnbTved9 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3iHTapEPgTL4WNqnbTved9]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3iHTapEPgTL4WNqnbTved9]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3iHTapEPgTL4WNqnbTved9]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3iHTapEPgTL4WNqnbTved9">
#     <div class="ipyplot-placeholder-div-3iHTapEPgTL4WNqnbTved9">
#         <div id="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-WLwEn8mzdqKN7fFoiKSHwm" class="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Collide</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-WLwEn8mzdqKN7fFoiKSHwm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3iHTapEPgTL4WNqnbTved9">
#         <div id="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-ALn6H7De5EFz7AF66MkV4v" class="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Winter King</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-ALn6H7De5EFz7AF66MkV4v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3iHTapEPgTL4WNqnbTved9">
#         <div id="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-LE2hXgAsskfTo89QNkMbix" class="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Do or Die</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=iqOGnAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=iqOGnAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-LE2hXgAsskfTo89QNkMbix">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3iHTapEPgTL4WNqnbTved9">
#         <div id="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-nfAdDLM34yaoWXn46KaXed" class="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Letting Go</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=C7eMDQAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=C7eMDQAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-nfAdDLM34yaoWXn46KaXed">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3iHTapEPgTL4WNqnbTved9">
#         <div id="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-X2gDsr4Va25htQxrYQeKpu" class="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Rule Breaker</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=VexvDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=VexvDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-X2gDsr4Va25htQxrYQeKpu">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3iHTapEPgTL4WNqnbTved9">
#         <div id="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-jmH5Lpo5iuWwdu9JqdsVsj" class="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Only With You</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=Q8ksnwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=Q8ksnwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-jmH5Lpo5iuWwdu9JqdsVsj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3iHTapEPgTL4WNqnbTved9">
#         <div id="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9-BsEYaG9SJvwAC8ZyWMfxvK" class="ipyplot-content-div-3iHTapEPgTL4WNqnbTved9">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Marriage Pact</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word
# 2015
#     <style>
#         #ipyplot-html-viewer-toggle-bGHL9cJcz9aiAugXoRZtVQ {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-bGHL9cJcz9aiAugXoRZtVQ {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-bGHL9cJcz9aiAugXoRZtVQ {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-bGHL9cJcz9aiAugXoRZtVQ:checked ~ #ipyplot-html-viewer-textarea-bGHL9cJcz9aiAugXoRZtVQ {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-bGHL9cJcz9aiAugXoRZtVQ:checked + #ipyplot-html-viewer-label-bGHL9cJcz9aiAugXoRZtVQ:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-bGHL9cJcz9aiAugXoRZtVQ">
#         <label id="ipyplot-html-viewer-label-bGHL9cJcz9aiAugXoRZtVQ" for="ipyplot-html-viewer-toggle-bGHL9cJcz9aiAugXoRZtVQ">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-bGHL9cJcz9aiAugXoRZtVQ" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-f4zHm4XHsr4WXKpKNceHU5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5 {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-f4zHm4XHsr4WXKpKNceHU5">
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-7bw7di5MearCDTdM53REBn" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Blessing. Lyn Cote. Tyndale, July 1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-7bw7di5MearCDTdM53REBn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9stLjLkpogs5ANx9q8jNWi" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Color of Light. Emilie Richards. Mira, July 28</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9stLjLkpogs5ANx9q8jNWi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-br7A5hnPUpkJkhkUdLby3v" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Married to a Perfect Stranger. Jane Ashford. Sourcebooks Casablanca, Mar. 3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-br7A5hnPUpkJkhkUdLby3v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9HYLwFrPKqgvtikqdyExfw" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Avelynn</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=CvBICgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=CvBICgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9HYLwFrPKqgvtikqdyExfw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-97WaZWY9LippCWcaSz6zVc" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Bitter Springs</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=Dt98rgEACAAJ&printsec=front
#         <style>
#         #ipyplot-imgs-container-div-f4zHm4XHsr4WXKpKNceHU5 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5 {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-f4zHm4XHsr4WXKpKNceHU5">
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-7bw7di5MearCDTdM53REBn" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Blessing. Lyn Cote. Tyndale, July 1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-7bw7di5MearCDTdM53REBn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9stLjLkpogs5ANx9q8jNWi" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Color of Light. Emilie Richards. Mira, July 28</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9stLjLkpogs5ANx9q8jNWi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-br7A5hnPUpkJkhkUdLby3v" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Married to a Perfect Stranger. Jane Ashford. Sourcebooks Casablanca, Mar. 3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9foVAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-br7A5hnPUpkJkhkUdLby3v">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9HYLwFrPKqgvtikqdyExfw" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Avelynn</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=CvBICgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=CvBICgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-9HYLwFrPKqgvtikqdyExfw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-97WaZWY9LippCWcaSz6zVc" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Bitter Springs</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=Dt98rgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=Dt98rgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-97WaZWY9LippCWcaSz6zVc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
#         <div id="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-E6QAxBGnhZCaRp5c4WZyQ6" class="ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Choose Your Own Love Story: Adventures in Dating, Do Overs, and Finding Your Happily Ever After</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=LgRSrgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=LgRSrgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-f4zHm4XHsr4WXKpKNceHU5-E6QAxBGnhZCaRp5c4WZyQ6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-f4zHm4XHsr4WXKpKNceHU5">
# ...
# 2023
#     <style>
#         #ipyplot-html-viewer-toggle-UUC7KgRcdzgrHFUJ6V3nrE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-UUC7KgRcdzgrHFUJ6V3nrE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-UUC7KgRcdzgrHFUJ6V3nrE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-UUC7KgRcdzgrHFUJ6V3nrE:checked ~ #ipyplot-html-viewer-textarea-UUC7KgRcdzgrHFUJ6V3nrE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-UUC7KgRcdzgrHFUJ6V3nrE:checked + #ipyplot-html-viewer-label-UUC7KgRcdzgrHFUJ6V3nrE:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-UUC7KgRcdzgrHFUJ6V3nrE">
#         <label id="ipyplot-html-viewer-label-UUC7KgRcdzgrHFUJ6V3nrE" for="ipyplot-html-viewer-toggle-UUC7KgRcdzgrHFUJ6V3nrE">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea
h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right:

# %%
listings_merged = df_listings_csv.merge(df_google_books_csv, how='left', on='ISBN')

# %%
for year in range(2013,2024):
    print(year)
    t = listings_merged.loc[(listings_merged['year']==year) & (listings_merged['ISBN']!="") & (listings_merged['id']!="9foVAAAAQBAJ")] # issue with nan
    ipyplot.plot_images(list(t['google_smallThumbnail']), list(t['title']), img_width=100)
# Out:
# 2013
#     <style>
#         #ipyplot-html-viewer-toggle-EbVoc9zhnaC72qdMmrcEFN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-EbVoc9zhnaC72qdMmrcEFN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-EbVoc9zhnaC72qdMmrcEFN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-EbVoc9zhnaC72qdMmrcEFN:checked ~ #ipyplot-html-viewer-textarea-EbVoc9zhnaC72qdMmrcEFN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-EbVoc9zhnaC72qdMmrcEFN:checked + #ipyplot-html-viewer-label-EbVoc9zhnaC72qdMmrcEFN:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-EbVoc9zhnaC72qdMmrcEFN">
#         <label id="ipyplot-html-viewer-label-EbVoc9zhnaC72qdMmrcEFN" for="ipyplot-html-viewer-toggle-EbVoc9zhnaC72qdMmrcEFN">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-EbVoc9zhnaC72qdMmrcEFN" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-3PtDfDcW9Pgm92mrtAMmNL {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3PtDfDcW9Pgm92mrtAMmNL">
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-6t4jpMU4QarMPQAxeuaSFT" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Sins of a Ruthless Rogue</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-6t4jpMU4QarMPQAxeuaSFT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ntjixZfd6hAAwQmGPoKdgg" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Run to You</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ntjixZfd6hAAwQmGPoKdgg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-eKjBa4tusytJsFTG2iHYLt" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Love at First Sight: A Cupid, Texas Novel</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-eKjBa4tusytJsFTG2iHYLt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ZB27eb5gxjN48xUjAppcYw" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Any Duchess Will Do</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ZB27eb5gxjN48xUjAppcYw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ZqH6tgBFEptHeT3BQv4S6d" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Once Upon a Tower</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"
#         <style>
#         #ipyplot-imgs-container-div-3PtDfDcW9Pgm92mrtAMmNL {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-3PtDfDcW9Pgm92mrtAMmNL">
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-6t4jpMU4QarMPQAxeuaSFT" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Sins of a Ruthless Rogue</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5GVBLgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-6t4jpMU4QarMPQAxeuaSFT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ntjixZfd6hAAwQmGPoKdgg" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Run to You</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=PLm6NlX1qMUC&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ntjixZfd6hAAwQmGPoKdgg">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-eKjBa4tusytJsFTG2iHYLt" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Love at First Sight: A Cupid, Texas Novel</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=jTUbwQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-eKjBa4tusytJsFTG2iHYLt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ZB27eb5gxjN48xUjAppcYw" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Any Duchess Will Do</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=5spmLwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ZB27eb5gxjN48xUjAppcYw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ZqH6tgBFEptHeT3BQv4S6d" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Once Upon a Tower</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=o9C_MgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-ZqH6tgBFEptHeT3BQv4S6d">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-cKk7esFsSYRwp7LAAELvuo" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">An English Bride in Scotland</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=j_TzngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=j_TzngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-cKk7esFsSYRwp7LAAELvuo">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-3PtDfDcW9Pgm92mrtAMmNL">
#         <div id="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL-5EB3bDHKCsCZ3RCnTbqrHd" class="ipyplot-content-div-3PtDfDcW9Pgm92mrtAMmNL">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Sum of All Kisses</h4>
#             <h4 style="font-size: 9px; padding-left: 10px;
# 2014
#     <style>
#         #ipyplot-html-viewer-toggle-DbeDwnVWamgJRqz4yg74Bo {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-DbeDwnVWamgJRqz4yg74Bo {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-DbeDwnVWamgJRqz4yg74Bo {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-DbeDwnVWamgJRqz4yg74Bo:checked ~ #ipyplot-html-viewer-textarea-DbeDwnVWamgJRqz4yg74Bo {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-DbeDwnVWamgJRqz4yg74Bo:checked + #ipyplot-html-viewer-label-DbeDwnVWamgJRqz4yg74Bo:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-DbeDwnVWamgJRqz4yg74Bo">
#         <label id="ipyplot-html-viewer-label-DbeDwnVWamgJRqz4yg74Bo" for="ipyplot-html-viewer-toggle-DbeDwnVWamgJRqz4yg74Bo">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-DbeDwnVWamgJRqz4yg74Bo" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-L6B8PfrVkSRPfznvNJFufk {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-L6B8PfrVkSRPfznvNJFufk">
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-bHDprDmDNH98guNvoqCA34" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Beautifully Damaged</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-bHDprDmDNH98guNvoqCA34">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-JwXyEuJncMCRTNFskQMEbZ" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">A Husband’s Regret</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-JwXyEuJncMCRTNFskQMEbZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-TW7DEsd4A5hApQQCPagBLy" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Collide</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-TW7DEsd4A5hApQQCPagBLy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-EbwXq84H2DkrMk6SthQKUv" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Awakening of Miss Prim</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-EbwXq84H2DkrMk6SthQKUv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-QBqQXheKK5XgKihVQ2eNCm" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Nowhere But Here</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&
#         <style>
#         #ipyplot-imgs-container-div-L6B8PfrVkSRPfznvNJFufk {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-L6B8PfrVkSRPfznvNJFufk">
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-bHDprDmDNH98guNvoqCA34" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Beautifully Damaged</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=9w5angEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-bHDprDmDNH98guNvoqCA34">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-JwXyEuJncMCRTNFskQMEbZ" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">A Husband’s Regret</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=6FTUngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-JwXyEuJncMCRTNFskQMEbZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-TW7DEsd4A5hApQQCPagBLy" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Collide</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=CaApngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-TW7DEsd4A5hApQQCPagBLy">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-EbwXq84H2DkrMk6SthQKUv" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Awakening of Miss Prim</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=vffvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-EbwXq84H2DkrMk6SthQKUv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-QBqQXheKK5XgKihVQ2eNCm" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Nowhere But Here</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=L_nvAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-QBqQXheKK5XgKihVQ2eNCm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-dvrhRraumvd9rtu578HbXz" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">When the Duke Was Wicked</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=vYmrnQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=vYmrnQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-dvrhRraumvd9rtu578HbXz">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-L6B8PfrVkSRPfznvNJFufk">
#         <div id="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk-moZatMvnSyZvbZkLKXXoPf" class="ipyplot-content-div-L6B8PfrVkSRPfznvNJFufk">
#             <h4 style="font-size: 12px; word-wrap: break-word;">The Winter King</h4>
#             <h4 style="font-size: 9px; padding-left: 1
# 2015
#     <style>
#         #ipyplot-html-viewer-toggle-6tcE5H7wsESFZYPPLjnTWq {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-6tcE5H7wsESFZYPPLjnTWq {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-6tcE5H7wsESFZYPPLjnTWq {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-6tcE5H7wsESFZYPPLjnTWq:checked ~ #ipyplot-html-viewer-textarea-6tcE5H7wsESFZYPPLjnTWq {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-6tcE5H7wsESFZYPPLjnTWq:checked + #ipyplot-html-viewer-label-6tcE5H7wsESFZYPPLjnTWq:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-6tcE5H7wsESFZYPPLjnTWq">
#         <label id="ipyplot-html-viewer-label-6tcE5H7wsESFZYPPLjnTWq" for="ipyplot-html-viewer-toggle-6tcE5H7wsESFZYPPLjnTWq">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-6tcE5H7wsESFZYPPLjnTWq" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-RHgYYjni9ExZ6fkJUQDV7t {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-RHgYYjni9ExZ6fkJUQDV7t">
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-dUGVvXQi3DuQaFxnNeqUcp" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Where Sea Meets Sky</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=1PGcBwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=1PGcBwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-dUGVvXQi3DuQaFxnNeqUcp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-PHksWtoKrc7CSiQTCPoovw" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Back in the Game: A Stardust, Texas, Novel</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=iM-PoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=iM-PoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-PHksWtoKrc7CSiQTCPoovw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-MK6FiKPF8uJ69mnuJqUGqV" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Broken</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=hdGIoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=hdGIoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-MK6FiKPF8uJ69mnuJqUGqV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-edBknwbbWrexa88o7JnEGZ" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Diary of an Accidental Wallflower: The Seduction Diaries, Book 1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=mv6WoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=mv6WoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-edBknwbbWrexa88o7JnEGZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-KtpbxzdTRVZ5VRMyFJtVMj" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Cursed by Fire: The Immortal Brothers</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=X_6ODQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.go
#         <style>
#         #ipyplot-imgs-container-div-RHgYYjni9ExZ6fkJUQDV7t {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t {
#             width: 100px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t {
#             width: 100px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t img {
#             width: 100px;
#         }
#
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-RHgYYjni9ExZ6fkJUQDV7t">
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-dUGVvXQi3DuQaFxnNeqUcp" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Where Sea Meets Sky</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=1PGcBwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=1PGcBwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-dUGVvXQi3DuQaFxnNeqUcp">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-PHksWtoKrc7CSiQTCPoovw" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Back in the Game: A Stardust, Texas, Novel</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=iM-PoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=iM-PoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-PHksWtoKrc7CSiQTCPoovw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-MK6FiKPF8uJ69mnuJqUGqV" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Broken</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=hdGIoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=hdGIoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-MK6FiKPF8uJ69mnuJqUGqV">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-edBknwbbWrexa88o7JnEGZ" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Diary of an Accidental Wallflower: The Seduction Diaries, Book 1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=mv6WoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api</h4><img src="http://books.google.com/books/content?id=mv6WoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-edBknwbbWrexa88o7JnEGZ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-KtpbxzdTRVZ5VRMyFJtVMj" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Cursed by Fire: The Immortal Brothers</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=X_6ODQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=X_6ODQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-KtpbxzdTRVZ5VRMyFJtVMj">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-ndGAYkcYELgWZzwVcMk3P7" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
#             <h4 style="font-size: 12px; word-wrap: break-word;">When Joss Met Matt</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">http://books.google.com/books/content?id=aflvDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api</h4><img src="http://books.google.com/books/content?id=aflvDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-ndGAYkcYELgWZzwVcMk3P7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-RHgYYjni9ExZ6fkJUQDV7t">
#         <div id="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t-YSUMrxTMj9wyGpwsW4iiq4" class="ipyplot-content-div-RHgYYjni9ExZ6fkJUQDV7t">
# ...
#     <style>
#         #ipyplot-html-viewer-toggle-mu8CeFXzsMjYVKijruQvkD {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-mu8CeFXzsMjYVKijruQvkD {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-mu8CeFXzsMjYVKijruQvkD {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-mu8CeFXzsMjYVKijruQvkD:checked ~ #ipyplot-html-viewer-textarea-mu8CeFXzsMjYVKijruQvkD {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-mu8CeFXzsMjYVKijruQvkD:checked + #ipyplot-html-viewer-label-mu8CeFXzsMjYVKijruQvkD:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-mu8CeFXzsMjYVKijruQvkD">
#         <label id="ipyplot-html-viewer-label-mu8CeFXzsMjYVKijruQvkD" for="ipyplot-html-viewer-toggle-mu8CeFXzsMjYVKijruQvkD">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea